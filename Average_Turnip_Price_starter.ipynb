# %% [markdown]
# # Review Session Problem: Average Turnip Pricing
# Written by Benjamin Chang (UBC)

# %% [markdown]
# ![how_to_keep_turnips_from_rotting_in_animal_crossing_new_horizons_1543222.jpg](attachment:how_to_keep_turnips_from_rotting_in_animal_crossing_new_horizons_1543222.jpg)

# %% [markdown]
# Daisy Mae has just visited your island on the Sunday, and you have purchased your usual amount of turnips. As usual you are worrying about the best time to sell your investments when your friend and fellow Animal Crossing player Gavin tells you a trick he has discovered. He says that the best time to sell is the morning since on average, turnip prices are higher compared to the afternoon price. Sleep is very precious to you and you do not want to wake up early unless absolutely necessary. To confirm his statement, you have collected a bunch of turnip pricings over many weeks and you have decided to design an analysis program that can take in a csv of turnip pricings and calculate whether the average price is higher in the mornings or afternoons.

# %% [markdown]
# **Step 1:** Design a data definition called **TurnipPricing** to represent the turnip pricings in Animal Crossing. A TurnipPricing consists of the day, the price of the turnip (in bells) and whether or not it is morning. (You may set day as a string rather than designing an enumeration) Afterwards design a data definition for a **list of TurnipPricing**.

# %%
from cs103 import*
import csv
from typing import NamedTuple, List

# %% [markdown]
# **Step 2:** Design the read function and any necessary helper functions that will produce a List[TurnipPricing] from a csv file.

# %% [markdown]
# **Step 3:** Make a systematic design plan below for your analyze function that takes in a List[TurnipPricing]. The function should produce True if the morning price is higher and False otherwise.

# %% [markdown]
# **Step 4:** Uncomment and run the examples below. These will be useful for your tests.

# %%
# TP100M = TurnipPricing("Monday", 100, True)
# TP100A = TurnipPricing("Monday", 100, False)
# TP200M = TurnipPricing("Tuesday", 200, True)
# TP200A = TurnipPricing("Tuesday", 200, False)
# TP300M = TurnipPricing("Wednesday", 300, True)
# TP300A = TurnipPricing("Wednesday", 300, False)
# TP400M = TurnipPricing("Thursday", 400, True)
# TP400A = TurnipPricing("Thursday", 400, False)
# TP500M = TurnipPricing("Friday", 500, True)
# TP500A = TurnipPricing("Friday", 500, False)

# MORNING_HIGHER = [TP300M, TP400M, TP500M, TP100A, TP200A, TP300A]
# AFTERNOON_HIGHER = [TP100M, TP200M, TP300M, TP300A, TP400A, TP500A]
# SAME_AVERAGE = [TP100M, TP200M, TP300M, TP400M, TP500M, TP100A, TP200A, TP300A, TP400A, TP500A]

# %% [markdown]
# **Step 5:** Complete your analyze function design and any necessary helper functions.

# %% [markdown]
# **Step 6:** Complete your main function.

# %%
# main("turnip_prices.csv")

# %% [markdown]
# ## Congratulations! We found out the best time to sell our turnips and become rich!
#
# ![tenor.gif](attachment:tenor.gif)
